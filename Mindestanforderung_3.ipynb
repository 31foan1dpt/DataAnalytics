# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
accidents_df = pd.read_csv('data/edited_file.csv', index_col='ID')

# %%
pd.set_option('display.max_columns', None)
accidents.head()
# Out:
#      Source  Severity           Start_Time             End_Time  Start_Lat  \
# ID
# 1   Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00  39.865147
# 2   Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59  39.928059
# 3   Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27  39.063148
# 4   Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34  39.747753
# 5   Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07  39.627781
#
#     Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# ID
# 1  -84.058723      NaN      NaN          0.01
# 2  -82.831184      NaN      NaN          0.01
# 3  -84.032608      NaN      NaN          0.01
# 4  -84.205582      NaN      NaN          0.01
# 5  -84.188354      NaN      NaN          0.01
#
#                                           Description  \
# ID
# 1   Right lane blocked due to accident on I-70 Eas...
# 2   Accident on Brice Rd at Tussing Rd. Expect del...
# ...

# %%
#calculate new column
accidents_df['country_state'] = accidents_df['State'].astype(str) + accidents_df['Country'].astype(str)
print(accidents_df['country_state'])
# Out:
# ID
# 1          OHUS
# 2          OHUS
# 3          OHUS
# 4          OHUS
# 5          OHUS
#            ...
# 7777757    CAUS
# 7777758    CAUS
# 7777759    CAUS
# 7777760    CAUS
# 7777761    CAUS
# Name: country_state, Length: 7728394, dtype: object

# %%
accidents_df
# Out:
#           Source  Severity           Start_Time             End_Time  \
# ID
# 1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...          ...       ...                  ...                  ...
# 7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...

# %%
merged_df = pd.concat([accidents_df, accidents_df['country_state']], axis=1)
merged_df
# Out:
#           Source  Severity           Start_Time             End_Time  \
# ID
# 1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...          ...       ...                  ...                  ...
# 7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...

# %%
pivot_table = merged_df.pivot_table 
pivot_table
# Out:
# <bound method DataFrame.pivot_table of           Source  Severity           Start_Time             End_Time  \
# ID
# 1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...          ...       ...                  ...                  ...
# 7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...
