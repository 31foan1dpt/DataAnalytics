# %%
#Assignment VidalDosSantos, Jelic, Forte

# %%
import numpy as np
import pandas as pd

# %%
#read-in data as pandaFrame
df = pd.read_csv('data/US_Accidents_March23.csv', index_col = 'ID')
#convert to numpy-Array in order to execute ops 
np_array = df.to_numpy()
print(np_array)
# Out:
# [['Source2' 3 '2016-02-08 05:46:00' ... 'Night' 'Night' 'Night']
#  ['Source2' 2 '2016-02-08 06:07:59' ... 'Night' 'Night' 'Day']
#  ['Source2' 2 '2016-02-08 06:49:27' ... 'Night' 'Day' 'Day']
#  ...
#  ['Source1' 2 '2019-08-23 19:00:21' ... 'Day' 'Day' 'Day']
#  ['Source1' 2 '2019-08-23 19:00:21' ... 'Day' 'Day' 'Day']
#  ['Source1' 2 '2019-08-23 18:52:06' ... 'Day' 'Day' 'Day']]

# %%
#filter data with 2 conditions
sourceArray = np_array[:,0]
severityArray = np_array[:,1]
temperatureArray = np_array[:,19]
filtered_data_severity = severityArray[np.argwhere(severityArray > 3)]
print(filtered_data_severity)
filtered_data_source = sourceArray[np.argwhere(sourceArray == 'Source1')]
print(filtered_data_source)
# Out:
# [[4]
#  [4]
#  [4]
#  ...
#  [4]
#  [4]
#  [4]]
# [['Source1']
#  ['Source1']
#  ['Source1']
#  ...
#  ['Source1']
#  ['Source1']
#  ['Source1']]

# %%
#2 statistics
print(np.mean(severityArray))
print(np.median(temperatureArray))
# Out:
# 2.212384487643875
# 63.0

# %%
#calculate new column
df['source_severity'] = df['Source'].astype(str) + df['Severity'].astype(str)
print(df['source_severity'])
# Out:
# ID
# A-1          Source23
# A-2          Source22
# A-3          Source22
# A-4          Source23
# A-5          Source22
#                ...
# A-7777757    Source12
# A-7777758    Source12
# A-7777759    Source12
# A-7777760    Source12
# A-7777761    Source12
# Name: source_severity, Length: 7728394, dtype: object

# %%
#change naming
df.rename(columns={'source_severity':'severity_source'})
# Out:
#             Source  Severity           Start_Time             End_Time  \
# ID
# A-1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# A-2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# A-3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# A-4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# A-5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...            ...       ...                  ...                  ...
# A-7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# A-7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# A-7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# A-7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# A-7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#            Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...

# %%
#change order of columns
cols = list(df.columns)
cols[-2], cols[-1] = cols[-1], cols[-2]
df = df[cols]
print(df)
# Out:
#             Source  Severity           Start_Time             End_Time  \
# ID
# A-1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# A-2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# A-3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# A-4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# A-5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...            ...       ...                  ...                  ...
# A-7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# A-7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# A-7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# A-7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# A-7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#            Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...

# %%
#delete column severity_source
df = df.drop('source_severity', axis=1)
print(df)
# Out:
#             Source  Severity           Start_Time             End_Time  \
# ID
# A-1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# A-2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# A-3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# A-4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# A-5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...            ...       ...                  ...                  ...
# A-7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# A-7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# A-7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# A-7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# A-7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#            Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...

# %%
#use str-Accesor --> replace ID (A-1 --> 1)
df.index = df.index.str.replace('A-','')
print(df)
# Out:
#           Source  Severity           Start_Time             End_Time  \
# ID
# 1        Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 2        Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 3        Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 4        Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 5        Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...          ...       ...                  ...                  ...
# 7777757  Source1         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 7777758  Source1         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 7777759  Source1         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 7777760  Source1         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 7777761  Source1         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# ...

# %%
df.to_csv('data/edited_file.csv')
