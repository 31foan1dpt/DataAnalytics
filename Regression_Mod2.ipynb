# %%
import statsmodels.api as sm
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from sklearn.preprocessing import LabelEncoder, StandardScaler
from category_encoders import TargetEncoder

# %%
#read in data
accidents = pd.read_csv('data/MA3_finished.csv', index_col='ID')
accidents = accidents.sample(frac=0.1)

# %%
#look at data
print(accidents.head)
# Out:
# <bound method NDFrame.head of          Unnamed: 0  Severity           Start_Time             End_Time  \
# ID
# 2486886     2486886         2  2018-06-14 16:09:59  2018-06-14 17:09:37
# 772867       772867         2  2021-09-20 06:52:39  2021-09-20 07:22:13
# 3522166     3522166         2  2022-03-10 16:10:06  2022-03-10 16:38:59
# 4839643     4839643         2  2022-08-27 12:31:41  2022-08-27 13:34:28
# 5365303     5365303         2  2021-07-29 08:10:35  2021-07-29 08:36:00
# ...             ...       ...                  ...                  ...
# 6473153     6473153         4  2020-03-20 18:02:35  2020-03-20 18:37:33
# 1315603     1315603         2  2020-05-30 10:55:23  2020-05-30 12:29:35
# 4169049     4169049         4  2022-11-05 21:17:00  2022-11-06 01:00:49
# 3340293     3340293         2  2022-10-07 05:53:00  2022-10-07 08:02:32
# 4394540     4394540         2  2022-09-23 16:58:05  2022-09-23 20:30:00
#
#          Start_Lat   Start_Lng  Distance(mi)  \
# ID
# 2486886  30.676197  -88.127373         0.000
# 772867   33.647110  -84.397804         0.000
# 3522166  35.269857  -80.794350         0.464
# 4839643  30.378275  -97.688442         0.278
# 5365303  33.705430 -117.855026         1.939
# ...            ...         ...           ...
# 6473153  29.981590  -90.253600         0.149
# 1315603  37.795937 -121.190788         0.000
# 4169049  32.645435  -96.856238         1.308
# 3340293  36.976302 -120.078228         0.076
# 4394540  34.068151 -118.027838         1.379
#
#                                                Description         Street  \
# ID
# 2486886  Accident on County Hwy-56 Airport Blvd Westbou...         I-65 S
# 772867   Right hand shoulder blocked due to accident on...       GA-401 N
# 3522166  Stationary traffic from US-29/NC-49/N Tryon St...      Munsee St
# 4839643  Slow traffic on TX-275 Loop from W Grady Dr (N...   N Lamar Blvd
# 5365303  Slow traffic on Costa Mesa Fwy S - CA-55 S fro...        CA-55 S
# ...                                                    ...            ...
# 6473153  Closed at Airport Access Rd - Road closed due ...     Airline Dr
# 1315603           Accident on CA-99 Northbound at CA-120 .        CA-99 N
# 4169049  I-20 E is closed from Wheatland Rd/Exit 465 (I...         I-20 E
# 3340293  Accident on CA-99 N from Cleveland Ave (CA-99)...          CA-99
# 4394540  Stationary traffic on I-10 W - San Bernardino ...         I-10 W
#
#               City  ... Nautical_Twilight Astronomical_Twilight  Year Month  \
# ID                  ...
# 2486886     Mobile  ...               Day                   Day  2018     6
# 772867     Atlanta  ...               Day                   Day  2021     9
# 3522166  Charlotte  ...               Day                   Day  2022     3
# 4839643     Austin  ...               Day                   Day  2022     8
# 5365303  Santa Ana  ...               Day                   Day  2021     7
# ...            ...  ...               ...                   ...   ...   ...
# 6473153     Kenner  ...               Day                   Day  2020     3
# 1315603    Manteca  ...               Day                   Day  2020     5
# 4169049     Dallas  ...             Night                 Night  2022    11
# 3340293     Madera  ...             Night                   Day  2022    10
# 4394540   El Monte  ...               Day                   Day  2022     9
#
#         Day Hour  Duration      State Name  Region            Division
# ID
# 2486886   3   16    3578.0         Alabama   South  East South Central
# 772867    0    6    1774.0         Georgia   South      South Atlantic
# 3522166   3   16    1733.0  North Carolina   South      South Atlantic
# 4839643   5   12    3767.0           Texas   South  West South Central
# 5365303   3    8    1525.0      California    West             Pacific
# ...      ..  ...       ...             ...     ...                 ...
# 6473153   4   18    2098.0       Louisiana   South  West South Central
# 1315603   5   10    5652.0      California    West             Pacific
# 4169049   5   21   13429.0           Texas   South  West South Central
# 3340293   4    5    7772.0      California    West             Pacific
# 4394540   4   16   12715.0      California    West             Pacific
#
# [705156 rows x 48 columns]>

# %%
#create copy for this file and drop unnamed column name
regression_df = accidents.copy()
regression_df.drop('Unnamed: 0', axis=1, inplace=True)
#check new df
regression_df.head()
# Out:
#          Severity           Start_Time             End_Time  Start_Lat  \
# ID
# 2486886         2  2018-06-14 16:09:59  2018-06-14 17:09:37  30.676197
# 772867          2  2021-09-20 06:52:39  2021-09-20 07:22:13  33.647110
# 3522166         2  2022-03-10 16:10:06  2022-03-10 16:38:59  35.269857
# 4839643         2  2022-08-27 12:31:41  2022-08-27 13:34:28  30.378275
# 5365303         2  2021-07-29 08:10:35  2021-07-29 08:36:00  33.705430
#
#           Start_Lng  Distance(mi)  \
# ID
# 2486886  -88.127373         0.000
# 772867   -84.397804         0.000
# 3522166  -80.794350         0.464
# 4839643  -97.688442         0.278
# 5365303 -117.855026         1.939
#
#                                                Description         Street  \
# ID
# 2486886  Accident on County Hwy-56 Airport Blvd Westbou...         I-65 S
# 772867   Right hand shoulder blocked due to accident on...       GA-401 N
# 3522166  Stationary traffic from US-29/NC-49/N Tryon St...      Munsee St
# 4839643  Slow traffic on TX-275 Loop from W Grady Dr (N...   N Lamar Blvd
# 5365303  Slow traffic on Costa Mesa Fwy S - CA-55 S fro...        CA-55 S
#
#               City       County  ... Nautical_Twilight Astronomical_Twilight  \
# ID                               ...
# 2486886     Mobile       Mobile  ...               Day                   Day
# 772867     Atlanta      Clayton  ...               Day                   Day
# 3522166  Charlotte  Mecklenburg  ...               Day                   Day
# 4839643     Austin       Travis  ...               Day                   Day
# 5365303  Santa Ana       Orange  ...               Day                   Day
#
#          Year Month Day  Hour  Duration      State Name  Region  \
# ID
# 2486886  2018     6   3    16    3578.0         Alabama   South
# 772867   2021     9   0     6    1774.0         Georgia   South
# 3522166  2022     3   3    16    1733.0  North Carolina   South
# 4839643  2022     8   5    12    3767.0           Texas   South
# 5365303  2021     7   3     8    1525.0      California    West
#
#                    Division
# ID
# 2486886  East South Central
# 772867       South Atlantic
# 3522166      South Atlantic
# 4839643  West South Central
# 5365303             Pacific
#
# [5 rows x 47 columns]

# %%
#describe the data
regression_df.describe()
# Out:
#             Severity      Start_Lat      Start_Lng   Distance(mi)  \
# count  705156.000000  705156.000000  705156.000000  705156.000000
# mean        2.202698      36.193256     -94.567841       0.569845
# std         0.480788       5.117869      17.306861       1.730488
# min         1.000000      24.554800    -124.535893       0.000000
# 25%         2.000000      33.315374    -117.159039       0.000000
# 50%         2.000000      35.819729     -87.664725       0.037000
# 75%         2.000000      40.121761     -80.369779       0.479000
# max         4.000000      48.999569     -68.132190     175.679993
#
#        Temperature(F)    Humidity(%)   Pressure(in)  Visibility(mi)  \
# count   705156.000000  705156.000000  705156.000000   705156.000000
# mean        61.902302      64.376226      29.514160        9.101926
# std         19.042470      22.777913       1.014116        2.643746
# min        -35.000000       1.000000       2.990000        0.000000
# 25%         49.500000      48.000000      29.340000       10.000000
# 50%         64.000000      66.000000      29.840000       10.000000
# 75%         76.000000      84.000000      30.020000       10.000000
# max        196.000000     100.000000      58.390000      100.000000
#
#        Wind_Speed(mph)           Year          Month            Day  \
# count    705156.000000  705156.000000  705156.000000  705156.000000
# mean          7.691020    2020.028401       6.683036       2.599813
# std           5.563616       1.865549       3.635368       1.806146
# min           0.000000    2016.000000       1.000000       0.000000
# 25%           4.600000    2019.000000       3.000000       1.000000
# 50%           7.000000    2020.000000       7.000000       3.000000
# 75%          10.400000    2022.000000      10.000000       4.000000
# max         822.800000    2023.000000      12.000000       6.000000
#
#                 Hour      Duration
# count  705156.000000  7.051560e+05
# mean       12.439467  2.609651e+04
# std         5.428459  7.956168e+05
# min         0.000000  1.800000e+02
# 25%         8.000000  2.059000e+03
# 50%        13.000000  4.502000e+03
# 75%        17.000000  7.546000e+03
# max        23.000000  1.341813e+08

# %%
#Wind_Speed 822 mph --> outliner
#print(regression_df.index[accidents ['Wind_Speed(mph)'] >822].tolist())
#print(regression_df.loc[[86481]])
#regression_df.drop(labels=[86481],axis=0, inplace=True)

# %%
#Wind_Speed 243 mph --> outliner
#print(regression_df.index[regression_df ['Wind_Speed(mph)'] >242].tolist())
#print (regression_df.loc[[776748]])
#regression_df.drop(labels=[776748],axis=0, inplace=True)

# %%
regression_df.dtypes
# Out:
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# Description               object
# Street                    object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Temperature(F)           float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# Year                       int64
# Month                      int64
# Day                        int64
# Hour                       int64
# Duration                 float64
# State Name                object
# Region                    object
# Division                  object
# dtype: object

# %%
#Rename Columns with () or ' ' for the equation --> otherwise it leads to PatsyError
regression_df = regression_df.rename(columns={
    'Temperature(F)': 'Temperature',
    'Humidity(%)': 'Humidity',
    'Visibility(mi)': 'Visibility',
    'Pressure(in)': 'Pressure',
    'Wind_Speed(mph)': 'Wind_Speed',
    'Distance(mi)': 'Distance',
    'State Name': 'StateName',
})

# %%
#basic linearRegressionModel
severity_basic = ols("Severity ~ Weather_Condition", regression_df).fit()
print(severity_basic.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Severity   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     205.7
# Date:                Fri, 05 Jan 2024   Prob (F-statistic):               0.00
# Time:                        13:44:57   Log-Likelihood:            -4.7273e+05
# No. Observations:              705156   AIC:                         9.457e+05
# Df Residuals:                  705042   BIC:                         9.470e+05
# Df Model:                         113
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               2.0870      0.099     21.156      0.000       1.894       2.280
# Weather_Condition[T.Blowing Dust / Windy]              -0.0224      0.130     -0.172      0.863      -0.278       0.233
# Weather_Condition[T.Blowing Snow]                       0.2597      0.113      2.303      0.021       0.039       0.481
# Weather_Condition[T.Blowing Snow / Windy]              -0.0474      0.109     -0.433      0.665      -0.262       0.167
# Weather_Condition[T.Clear]                              0.2763      0.099      2.801      0.005       0.083       0.470
# Weather_Condition[T.Cloudy]                             0.0718      0.099      0.728      0.467      -0.122       0.265
# Weather_Condition[T.Cloudy / Windy]                     0.0753      0.099      0.758      0.448      -0.119       0.270
# Weather_Condition[T.Drifting Snow / Windy]              0.9130      0.349      2.618      0.009       0.229       1.597
# Weather_Condition[T.Drizzle]                            0.1748      0.101      1.723      0.085      -0.024       0.374
# Weather_Condition[T.Drizzle / Windy]                   -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Drizzle and Fog]                    0.1130      0.121      0.932      0.351      -0.125       0.351
# Weather_Condition[T.Dust Whirls]                       -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Fair]                               0.0397      0.099      0.403      0.687      -0.154       0.233
# Weather_Condition[T.Fair / Windy]                       0.0565      0.099      0.571      0.568      -0.138       0.250
# Weather_Condition[T.Fog]                                0.0405      0.099      0.410      0.682      -0.153       0.234
# Weather_Condition[T.Fog / Windy]                        0.0242      0.113      0.213      0.831      -0.198       0.246
# Weather_Condition[T.Freezing Drizzle]                  -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Freezing Rain]                      0.2630      0.145      1.819      0.069      -0.020       0.547
# Weather_Condition[T.Funnel Cloud]                      -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Hail]                              -0.0870      0.256     -0.339      0.734      -0.589       0.415
# Weather_Condition[T.Haze]                               0.1082      0.099      1.095      0.274      -0.085       0.302
# Weather_Condition[T.Haze / Windy]                       0.0098      0.106      0.093      0.926      -0.197       0.217
# Weather_Condition[T.Heavy Drizzle]                      0.2366      0.128      1.852      0.064      -0.014       0.487
# Weather_Condition[T.Heavy Freezing Drizzle]            -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Heavy Freezing Rain]                0.4130      0.349      1.184      0.236      -0.271       1.097
# Weather_Condition[T.Heavy Ice Pellets]                  0.4130      0.349      1.184      0.236      -0.271       1.097
# Weather_Condition[T.Heavy Rain]                         0.1764      0.099      1.782      0.075      -0.018       0.370
# Weather_Condition[T.Heavy Rain / Windy]                 0.0464      0.106      0.438      0.662      -0.161       0.254
# Weather_Condition[T.Heavy Rain Shower]                 -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Heavy Rain Showers]                 0.9130      0.349      2.618      0.009       0.229       1.597
# Weather_Condition[T.Heavy Sleet]                       -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Heavy Snow]                         0.1309      0.101      1.296      0.195      -0.067       0.329
# Weather_Condition[T.Heavy Snow / Windy]                 0.0267      0.111      0.241      0.810      -0.190       0.244
# Weather_Condition[T.Heavy T-Storm]                      0.1105      0.100      1.107      0.268      -0.085       0.306
# Weather_Condition[T.Heavy T-Storm / Windy]              0.0510      0.108      0.472      0.637      -0.161       0.263
# Weather_Condition[T.Heavy Thunderstorms and Rain]       0.3664      0.103      3.546      0.000       0.164       0.569
# Weather_Condition[T.Ice Pellets]                        0.6403      0.173      3.692      0.000       0.300       0.980
# Weather_Condition[T.Light Drizzle]                      0.1727      0.099      1.741      0.082      -0.022       0.367
# Weather_Condition[T.Light Drizzle / Windy]              0.2464      0.138      1.785      0.074      -0.024       0.517
# Weather_Condition[T.Light Freezing Drizzle]             0.2339      0.107      2.191      0.028       0.025       0.443
# Weather_Condition[T.Light Freezing Fog]                 0.3212      0.120      2.686      0.007       0.087       0.556
# Weather_Condition[T.Light Freezing Rain]                0.2714      0.102      2.649      0.008       0.071       0.472
# Weather_Condition[T.Light Freezing Rain / Windy]        0.0040      0.173      0.023      0.982      -0.336       0.344
# Weather_Condition[T.Light Hail]                         0.9130      0.483      1.889      0.059      -0.034       1.860
# Weather_Condition[T.Light Haze]                        -0.0870      0.349     -0.249      0.803      -0.771       0.597
# Weather_Condition[T.Light Ice Pellets]                  0.5630      0.145      3.893      0.000       0.280       0.847
# Weather_Condition[T.Light Rain]                         0.1515      0.099      1.535      0.125      -0.042       0.345
# Weather_Condition[T.Light Rain / Windy]                 0.1031      0.100      1.030      0.303      -0.093       0.299
# Weather_Condition[T.Light Rain Shower]                  0.1777      0.128      1.392      0.164      -0.073       0.428
# Weather_Condition[T.Light Rain Showers]                 0.0797      0.168      0.473      0.636      -0.250       0.410
# Weather_Condition[T.Light Rain with Thunder]            0.1158      0.099      1.163      0.245      -0.079       0.311
# Weather_Condition[T.Light Sleet]                       -0.0155      0.133     -0.117      0.907      -0.276       0.245
# Weather_Condition[T.Light Sleet / Windy]               -0.0870      0.349     -0.249      0.803      -0.771       0.597
# Weather_Condition[T.Light Snow]                         0.1546      0.099      1.566      0.117      -0.039       0.348
# Weather_Condition[T.Light Snow / Windy]                 0.0401      0.100      0.400      0.689      -0.157       0.237
# Weather_Condition[T.Light Snow Grains]                  0.9130      0.483      1.889      0.059      -0.034       1.860
# Weather_Condition[T.Light Snow Shower]                  0.2464      0.217      1.136      0.256      -0.179       0.671
# Weather_Condition[T.Light Snow Shower / Windy]         -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Light Snow Showers]                -0.0870      0.349     -0.249      0.803      -0.771       0.597
# Weather_Condition[T.Light Snow and Sleet]               0.1273      0.160      0.794      0.427      -0.187       0.442
# Weather_Condition[T.Light Snow and Sleet / Windy]      -0.0870      0.233     -0.373      0.710      -0.544       0.371
# Weather_Condition[T.Light Snow with Thunder]            0.1130      0.233      0.484      0.628      -0.344       0.571
# Weather_Condition[T.Light Thunderstorms and Rain]       0.3613      0.101      3.570      0.000       0.163       0.560
# Weather_Condition[T.Light Thunderstorms and Snow]       0.9130      0.290      3.144      0.002       0.344       1.482
# Weather_Condition[T.Mist]                               0.2005      0.103      1.942      0.052      -0.002       0.403
# Weather_Condition[T.Mist / Windy]                      -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Mostly Cloudy]                      0.1326      0.099      1.344      0.179      -0.061       0.326
# Weather_Condition[T.Mostly Cloudy / Windy]              0.0801      0.099      0.807      0.420      -0.115       0.275
# Weather_Condition[T.N/A Precipitation]                  0.0732      0.102      0.715      0.474      -0.127       0.274
# Weather_Condition[T.Overcast]                           0.3006      0.099      3.046      0.002       0.107       0.494
# Weather_Condition[T.Partial Fog]                       -0.0870      0.256     -0.339      0.734      -0.589       0.415
# Weather_Condition[T.Partly Cloudy]                      0.1234      0.099      1.251      0.211      -0.070       0.317
# Weather_Condition[T.Partly Cloudy / Windy]              0.1040      0.100      1.043      0.297      -0.092       0.300
# Weather_Condition[T.Patches of Fog]                     0.1164      0.102      1.137      0.256      -0.084       0.317
# Weather_Condition[T.Patches of Fog / Windy]             1.4130      0.349      4.052      0.000       0.729       2.097
# Weather_Condition[T.Rain]                               0.1637      0.099      1.657      0.098      -0.030       0.357
# Weather_Condition[T.Rain / Windy]                       0.0359      0.104      0.346      0.729      -0.167       0.239
# Weather_Condition[T.Rain Shower]                        0.2464      0.217      1.136      0.256      -0.179       0.671
# Weather_Condition[T.Rain Showers]                       0.4845      0.204      2.372      0.018       0.084       0.885
# Weather_Condition[T.Sand / Dust Whirls Nearby]         -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Sand / Dust Whirlwinds]             0.1630      0.256      0.636      0.525      -0.339       0.665
# Weather_Condition[T.Sand / Dust Whirlwinds / Windy]    -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Scattered Clouds]                   0.2952      0.099      2.991      0.003       0.102       0.489
# Weather_Condition[T.Shallow Fog]                        0.0316      0.103      0.307      0.759      -0.170       0.234
# Weather_Condition[T.Shallow Fog / Windy]               -0.0870      0.349     -0.249      0.803      -0.771       0.597
# Weather_Condition[T.Showers in the Vicinity]            0.1479      0.106      1.396      0.163      -0.060       0.356
# Weather_Condition[T.Sleet]                              0.0130      0.179      0.073      0.942      -0.338       0.364
# Weather_Condition[T.Sleet / Windy]                     -0.0870      0.217     -0.401      0.688      -0.512       0.338
# Weather_Condition[T.Small Hail]                         0.0797      0.217      0.368      0.713      -0.345       0.505
# Weather_Condition[T.Smoke]                              0.1177      0.100      1.182      0.237      -0.077       0.313
# Weather_Condition[T.Smoke / Windy]                      0.7130      0.233      3.055      0.002       0.256       1.171
# Weather_Condition[T.Snow]                               0.1017      0.099      1.022      0.307      -0.093       0.297
# Weather_Condition[T.Snow / Windy]                       0.0442      0.108      0.411      0.681      -0.167       0.255
# Weather_Condition[T.Snow Grains]                       -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Snow and Sleet]                     0.0973      0.125      0.778      0.436      -0.148       0.342
# Weather_Condition[T.Snow and Sleet / Windy]            -0.0870      0.149     -0.584      0.559      -0.379       0.205
# Weather_Condition[T.Snow and Thunder]                  -0.0870      0.290     -0.299      0.765      -0.656       0.482
# Weather_Condition[T.Squalls]                           -0.0870      0.290     -0.299      0.765      -0.656       0.482
# Weather_Condition[T.Squalls / Windy]                    0.5797      0.290      1.996      0.046       0.011       1.149
# Weather_Condition[T.T-Storm]                            0.1167      0.099      1.175      0.240      -0.078       0.311
# Weather_Condition[T.T-Storm / Windy]                    0.0961      0.114      0.847      0.397      -0.126       0.319
# Weather_Condition[T.Thunder]                            0.0558      0.099      0.561      0.575      -0.139       0.251
# Weather_Condition[T.Thunder / Windy]                    0.1630      0.116      1.405      0.160      -0.064       0.390
# Weather_Condition[T.Thunder / Wintry Mix]              -0.0870      0.483     -0.180      0.857      -1.034       0.860
# Weather_Condition[T.Thunder and Hail]                  -0.0870      0.349     -0.249      0.803      -0.771       0.597
# Weather_Condition[T.Thunder in the Vicinity]            0.0714      0.099      0.719      0.472      -0.123       0.266
# Weather_Condition[T.Thunderstorm]                       0.3168      0.102      3.117      0.002       0.118       0.516
# Weather_Condition[T.Thunderstorms and Rain]             0.3643      0.104      3.493      0.000       0.160       0.569
# Weather_Condition[T.Thunderstorms and Snow]             0.9130      0.483      1.889      0.059      -0.034       1.860
# Weather_Condition[T.Tornado]                           -0.2870      0.233     -1.229      0.219      -0.744       0.171
# Weather_Condition[T.Widespread Dust]                   -0.0870      0.154     -0.565      0.572      -0.389       0.215
# Weather_Condition[T.Widespread Dust / Windy]           -0.0870      0.290     -0.299      0.765      -0.656       0.482
# Weather_Condition[T.Wintry Mix]                         0.0780      0.100      0.783      0.434      -0.117       0.273
# Weather_Condition[T.Wintry Mix / Windy]                 0.0494      0.122      0.406      0.685      -0.189       0.288
# ==============================================================================
# Omnibus:                   250107.832   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           822171.311
# Skew:                           1.839   Prob(JB):                         0.00
# Kurtosis:                       6.803   Cond. No.                     2.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
severity_full = ols("Severity ~ Start_Lat + Start_Lng + Distance + Temperature + Humidity + Pressure + Visibility + Wind_Speed + Amenity + Bump + Crossing + Give_Way + Junction + No_Exit + Railway + Roundabout + Station + Stop + Traffic_Calming + Traffic_Signal + Turning_Loop + Year + Month + Day + Hour + Duration", regression_df).fit()
print(severity_full.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Severity   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     3214.
# Date:                Fri, 05 Jan 2024   Prob (F-statistic):               0.00
# Time:                        13:49:38   Log-Likelihood:            -4.4611e+05
# No. Observations:              705156   AIC:                         8.923e+05
# Df Residuals:                  705130   BIC:                         8.926e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 152.1219      0.639    238.217      0.000     150.870     153.373
# Amenity[T.True]            -0.0526      0.005    -10.467      0.000      -0.062      -0.043
# Bump[T.True]               -0.0428      0.034     -1.249      0.212      -0.110       0.024
# Crossing[T.True]           -0.0873      0.002    -43.089      0.000      -0.091      -0.083
# Give_Way[T.True]            0.0133      0.008      1.643      0.100      -0.003       0.029
# Junction[T.True]            0.0329      0.002     15.582      0.000       0.029       0.037
# No_Exit[T.True]            -0.0197      0.011     -1.827      0.068      -0.041       0.001
# Railway[T.True]             0.0390      0.006      6.442      0.000       0.027       0.051
# Roundabout[T.True]          0.0100      0.102      0.098      0.922      -0.190       0.210
# Station[T.True]            -0.0509      0.003    -14.599      0.000      -0.058      -0.044
# Stop[T.True]               -0.1144      0.003    -34.062      0.000      -0.121      -0.108
# Traffic_Calming[T.True]     0.0379      0.024      1.608      0.108      -0.008       0.084
# Traffic_Signal[T.True]     -0.1415      0.002    -79.411      0.000      -0.145      -0.138
# Turning_Loop[T.True]     7.229e-15   1.83e-13      0.039      0.969   -3.52e-13    3.66e-13
# Start_Lat                   0.0047      0.000     38.112      0.000       0.004       0.005
# Start_Lng                   0.0023    3.3e-05     70.711      0.000       0.002       0.002
# Distance                    0.0129      0.000     40.364      0.000       0.012       0.014
# Temperature                 0.0003   3.51e-05      8.271      0.000       0.000       0.000
# Humidity                    0.0003   2.91e-05     11.614      0.000       0.000       0.000
# Pressure                   -0.0155      0.001    -26.667      0.000      -0.017      -0.014
# Visibility                  0.0017      0.000      7.710      0.000       0.001       0.002
# Wind_Speed                  0.0006      0.000      6.163      0.000       0.000       0.001
# Year                       -0.0740      0.000   -236.073      0.000      -0.075      -0.073
# Month                      -0.0085      0.000    -55.024      0.000      -0.009      -0.008
# Day                         0.0103      0.000     33.972      0.000       0.010       0.011
# Hour                        0.0022      0.000     20.943      0.000       0.002       0.002
# Duration                 1.644e-09   6.82e-10      2.410      0.016    3.07e-10    2.98e-09
# ==============================================================================
# Omnibus:                   240279.874   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           817249.315
# Skew:                           1.739   Prob(JB):                         0.00
# Kurtosis:                       6.964   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.43e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
