# %%
import pandas as pd

accidents = pd.read_csv('data/edited_file.csv', index_col='ID')
accidents.dtypes
# Out:
# Unnamed: 0                 int64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Street                    object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# Year                       int64
# Month                      int64
# Day                        int64
# Hour                       int64
# Duration                 float64
# State Name                object
# Region                    object
# Division                  object
# dtype: object

# %%
# Start_Time and End_Time are objects, so we will convert them to DateTime-Objects

accidents['Start_Time'] = pd.to_datetime(accidents['Start_Time'])
accidents['End_Time'] = pd.to_datetime(accidents['End_Time'])

# after that we are able to extract hour, day, month and year of each date

accidents['Hour'] = accidents['Start_Time'].dt.hour
accidents['Day'] = accidents['Start_Time'].dt.day
accidents['Month'] = accidents['Start_Time'].dt.month
accidents['Year'] = accidents['Start_Time'].dt.year

# we will just clean the other datatypes here:
accidents['Weather_Timestamp'] = pd.to_datetime(accidents['Weather_Timestamp'])

# we will see the new added columns (extracted partss of the start date time)
accidents.head()
# Out:
#          Unnamed: 0  Severity          Start_Time            End_Time  \
# ID
# Source2           0         3 2016-02-08 05:46:00 2016-02-08 11:00:00
# Source2           1         2 2016-02-08 06:07:59 2016-02-08 06:37:59
# Source2           2         2 2016-02-08 06:49:27 2016-02-08 07:19:27
# Source2           3         3 2016-02-08 07:23:34 2016-02-08 07:53:34
# Source2           4         2 2016-02-08 07:39:07 2016-02-08 08:09:07
#
#          Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# ID
# Source2  39.865147 -84.058723      NaN      NaN          0.01
# Source2  39.928059 -82.831184      NaN      NaN          0.01
# Source2  39.063148 -84.032608      NaN      NaN          0.01
# Source2  39.747753 -84.205582      NaN      NaN          0.01
# Source2  39.627781 -84.188354      NaN      NaN          0.01
#
#                                                Description  ...  \
# ID                                                          ...
# Source2  Right lane blocked due to accident on I-70 Eas...  ...
# Source2  Accident on Brice Rd at Tussing Rd. Expect del...  ...
# Source2  Accident on OH-32 State Route 32 Westbound at ...  ...
# Source2  Accident on I-75 Southbound at Exits 52 52B US...  ...
# Source2  Accident on McEwen Rd at OH-725 Miamisburg Cen...  ...
#
#         Nautical_Twilight Astronomical_Twilight  Year Month Day Hour Duration  \
# ID
# Source2             Night                 Night  2016     2   8    5  18840.0
# Source2             Night                   Day  2016     2   8    6   1800.0
# Source2               Day                   Day  2016     2   8    6   1800.0
# Source2               Day                   Day  2016     2   8    7   1800.0
# Source2               Day                   Day  2016     2   8    7   1800.0
#
#         State Name   Region            Division
# ID
# Source2       Ohio  Midwest  East North Central
# Source2       Ohio  Midwest  East North Central
# Source2       Ohio  Midwest  East North Central
# Source2       Ohio  Midwest  East North Central
# Source2       Ohio  Midwest  East North Central
#
# [5 rows x 53 columns]

# %%
nan_count = accidents['Temperature(F)'].isna().sum()

print(f"Anzahl der NaN-Werte in der 'Temperature(F)'-Spalte: {nan_count}")
# Out:
# Anzahl der NaN-Werte in der 'Temperature(F)'-Spalte: 163853

# %%
# Example for Binning

#dropping al NaN (Temperature) rows
accidents_cleaned = accidents.dropna(subset=['Temperature(F)'])

#setting edges by ourself, because otherwise all tempperatures will result in 'moderate' when we let it automatically decide
bin_edges = [float('-inf'), 32, 50, 65, 80, float('inf')]
bin_labels = ['Very Cold', 'Cold', 'Moderate', 'Warm', 'Hot']
# Setting bins to 5, could also set 3 (cold, moderate, hot)
accidents_cleaned['Temperature_Bin'] = pd.cut(accidents_cleaned['Temperature(F)'], bins=bin_edges, labels=bin_labels)

accidents_cleaned
# Out:
# C:\Users\Vinko Jelic\AppData\Local\Temp\ipykernel_19148\1734423199.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents_cleaned['Temperature_Bin'] = pd.cut(accidents_cleaned['Temperature(F)'], bins=bin_edges, labels=bin_labels)
#          Unnamed: 0  Severity          Start_Time            End_Time  \
# ID
# Source2           0         3 2016-02-08 05:46:00 2016-02-08 11:00:00
# Source2           1         2 2016-02-08 06:07:59 2016-02-08 06:37:59
# Source2           2         2 2016-02-08 06:49:27 2016-02-08 07:19:27
# Source2           3         3 2016-02-08 07:23:34 2016-02-08 07:53:34
# Source2           4         2 2016-02-08 07:39:07 2016-02-08 08:09:07
# ...             ...       ...                 ...                 ...
# Source1     7728389         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# Source1     7728390         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# Source1     7728391         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# Source1     7728392         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# Source1     7728393         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# Source2  39.865147  -84.058723       NaN        NaN         0.010
# Source2  39.928059  -82.831184       NaN        NaN         0.010
# Source2  39.063148  -84.032608       NaN        NaN         0.010
# Source2  39.747753  -84.205582       NaN        NaN         0.010
# Source2  39.627781  -84.188354       NaN        NaN         0.010
# ...            ...         ...       ...        ...           ...
# Source1  34.002480 -117.379360  33.99888 -117.37094         0.543
# Source1  32.766960 -117.148060  32.76555 -117.15363         0.338
# Source1  33.775450 -117.847790  33.77740 -117.85727         0.561
# Source1  33.992460 -118.403020  33.98311 -118.39565         0.772
# Source1  34.133930 -117.230920  34.13736 -117.23934         0.537
#
#                                                Description  ...  \
# ID                                                          ...
# Source2  Right lane blocked due to accident on I-70 Eas...  ...
# Source2  Accident on Brice Rd at Tussing Rd. Expect del...  ...
# Source2  Accident on OH-32 State Route 32 Westbound at ...  ...
# Source2  Accident on I-75 Southbound at Exits 52 52B US...  ...
# Source2  Accident on McEwen Rd at OH-725 Miamisburg Cen...  ...
# ...                                                    ...  ...
# Source1                           At Market St - Accident.  ...
# Source1    At Camino Del Rio/Mission Center Rd - Accident.  ...
# Source1  At Glassell St/Grand Ave - Accident. in the ri...  ...
# Source1     At CA-90/Marina Fwy/Jefferson Blvd - Accident.  ...
# Source1              At Highland Ave/Arden Ave - Accident.  ...
#
#         Astronomical_Twilight  Year Month Day Hour Duration  State Name  \
# ID
# Source2                 Night  2016     2   8    5  18840.0        Ohio
# Source2                   Day  2016     2   8    6   1800.0        Ohio
# Source2                   Day  2016     2   8    6   1800.0        Ohio
# Source2                   Day  2016     2   8    7   1800.0        Ohio
# Source2                   Day  2016     2   8    7   1800.0        Ohio
# ...                       ...   ...   ...  ..  ...      ...         ...
# Source1                   Day  2019     8  23   18   1716.0  California
# Source1                   Day  2019     8  23   19   1613.0  California
# Source1                   Day  2019     8  23   19   1708.0  California
# Source1                   Day  2019     8  23   19   1761.0  California
# Source1                   Day  2019     8  23   18   1765.0  California
#
#           Region            Division  Temperature_Bin
# ID
# Source2  Midwest  East North Central             Cold
# Source2  Midwest  East North Central             Cold
# Source2  Midwest  East North Central             Cold
# Source2  Midwest  East North Central             Cold
# Source2  Midwest  East North Central             Cold
# ...          ...                 ...              ...
# Source1     West             Pacific              Hot
# Source1     West             Pacific             Warm
# Source1     West             Pacific             Warm
# Source1     West             Pacific             Warm
# Source1     West             Pacific             Warm
#
# [7564541 rows x 54 columns]

# %%
#One-Hot-Encoding
#Encoding all Weather Conditions

accidents_cleaned = pd.get_dummies(accidents_cleaned, columns=['Weather_Condition'], drop_first=True, prefix='Weather')
accidents_cleaned
# Out:
#          Unnamed: 0  Severity          Start_Time            End_Time  \
# ID
# Source2           0         3 2016-02-08 05:46:00 2016-02-08 11:00:00
# Source2           1         2 2016-02-08 06:07:59 2016-02-08 06:37:59
# Source2           2         2 2016-02-08 06:49:27 2016-02-08 07:19:27
# Source2           3         3 2016-02-08 07:23:34 2016-02-08 07:53:34
# Source2           4         2 2016-02-08 07:39:07 2016-02-08 08:09:07
# ...             ...       ...                 ...                 ...
# Source1     7728389         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# Source1     7728390         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# Source1     7728391         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# Source1     7728392         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# Source1     7728393         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# Source2  39.865147  -84.058723       NaN        NaN         0.010
# Source2  39.928059  -82.831184       NaN        NaN         0.010
# Source2  39.063148  -84.032608       NaN        NaN         0.010
# Source2  39.747753  -84.205582       NaN        NaN         0.010
# Source2  39.627781  -84.188354       NaN        NaN         0.010
# ...            ...         ...       ...        ...           ...
# Source1  34.002480 -117.379360  33.99888 -117.37094         0.543
# Source1  32.766960 -117.148060  32.76555 -117.15363         0.338
# Source1  33.775450 -117.847790  33.77740 -117.85727         0.561
# Source1  33.992460 -118.403020  33.98311 -118.39565         0.772
# Source1  34.133930 -117.230920  34.13736 -117.23934         0.537
#
#                                                Description  ...  \
# ID                                                          ...
# Source2  Right lane blocked due to accident on I-70 Eas...  ...
# Source2  Accident on Brice Rd at Tussing Rd. Expect del...  ...
# Source2  Accident on OH-32 State Route 32 Westbound at ...  ...
# Source2  Accident on I-75 Southbound at Exits 52 52B US...  ...
# Source2  Accident on McEwen Rd at OH-725 Miamisburg Cen...  ...
# ...                                                    ...  ...
# Source1                           At Market St - Accident.  ...
# Source1    At Camino Del Rio/Mission Center Rd - Accident.  ...
# Source1  At Glassell St/Grand Ave - Accident. in the ri...  ...
# Source1     At CA-90/Marina Fwy/Jefferson Blvd - Accident.  ...
# Source1              At Highland Ave/Arden Ave - Accident.  ...
#
#         Weather_Thunder in the Vicinity Weather_Thunderstorm  \
# ID
# Source2                           False                False
# Source2                           False                False
# Source2                           False                False
# Source2                           False                False
# Source2                           False                False
# ...                                 ...                  ...
# Source1                           False                False
# Source1                           False                False
# Source1                           False                False
# Source1                           False                False
# Source1                           False                False
#
#         Weather_Thunderstorms and Rain Weather_Thunderstorms and Snow  \
# ID
# Source2                          False                          False
# Source2                          False                          False
# Source2                          False                          False
# Source2                          False                          False
# Source2                          False                          False
# ...                                ...                            ...
# Source1                          False                          False
# Source1                          False                          False
# Source1                          False                          False
# Source1                          False                          False
# Source1                          False                          False
#
#         Weather_Tornado Weather_Volcanic Ash Weather_Widespread Dust  \
# ID
# Source2           False                False                   False
# Source2           False                False                   False
# Source2           False                False                   False
# Source2           False                False                   False
# Source2           False                False                   False
# ...                 ...                  ...                     ...
# Source1           False                False                   False
# Source1           False                False                   False
# Source1           False                False                   False
# Source1           False                False                   False
# Source1           False                False                   False
#
#         Weather_Widespread Dust / Windy Weather_Wintry Mix  \
# ID
# Source2                           False              False
# Source2                           False              False
# Source2                           False              False
# Source2                           False              False
# Source2                           False              False
# ...                                 ...                ...
# Source1                           False              False
# Source1                           False              False
# Source1                           False              False
# Source1                           False              False
# Source1                           False              False
#
#          Weather_Wintry Mix / Windy
# ID
# Source2                       False
# Source2                       False
# Source2                       False
# Source2                       False
# Source2                       False
# ...                             ...
# Source1                       False
# Source1                       False
# Source1                       False
# Source1                       False
# Source1                       False
#
# [7564541 rows x 195 columns]

# %%
#Creating time series

# Konvertiere 'Start_Time' in ein DateTime-Objekt
accidents_cleaned['Start_Time'] = pd.to_datetime(accidents_cleaned['Start_Time'])

# Setze 'Start_Time' als Index für die Time Series
accidents_cleaned.set_index('Start_Time', inplace=True)

# %%
# Calculate daily accidents
daily_accidents = accidents_cleaned.resample('D').size()

# daily accidents graph
plt.figure(figsize=(12, 6))
daily_accidents.plot(title='Tägliche Unfallanzahl', xlabel='Datum', ylabel='Anzahl')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Calculate daily accidents
# ----> 2 daily_accidents = accidents_cleaned.resample('D').size()
#       4 # daily accidents graph
#       5 plt.figure(figsize=(12, 6))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:9439, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9436 else:
#    9437     axis = 0
# -> 9439 return get_resampler(
#    9440     cast("Series | DataFrame", self),
#    9441     freq=rule,
#    9442     label=label,
#    9443     closed=closed,
#    9444     axis=axis,
#    9445     kind=kind,
#    9446     convention=convention,
#    9447     key=on,
#    9448     level=level,
#    9449     origin=origin,
#    9450     offset=offset,
#    9451     group_keys=group_keys,
#    9452 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\resample.py:1970, in get_resampler(obj, kind, **kwds)
#    1966 """
#    1967 Create a TimeGrouper and return our resampler.
#    1968 """
#    1969 tg = TimeGrouper(**kwds)
# -> 1970 return tg._get_resampler(obj, kind=kind)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\resample.py:2134, in TimeGrouper._get_resampler(self, obj, kind)
#    2131 _, ax, indexer = self._set_grouper(obj, gpr_index=None)
#    2133 if isinstance(ax, DatetimeIndex):
# -> 2134     return DatetimeIndexResampler(
#    2135         obj,
#    2136         timegrouper=self,
#    2137         kind=kind,
#    2138         axis=self.axis,
#    2139         group_keys=self.group_keys,
#    2140         gpr_index=ax,
#    2141     )
#    2142 elif isinstance(ax, PeriodIndex) or kind == "period":
#    2143     return PeriodIndexResampler(
#    2144         obj,
#    2145         timegrouper=self,
#    (...)
#    2149         gpr_index=ax,
#    2150     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\resample.py:175, in Resampler.__init__(self, obj, timegrouper, axis, kind, gpr_index, group_keys, selection)
#     172 self.group_keys = group_keys
#     173 self.as_index = True
# --> 175 self.obj, self.ax, self._indexer = self._timegrouper._set_grouper(
#     176     self._convert_obj(obj), sort=True, gpr_index=gpr_index
#     177 )
#     178 self.binner, self.grouper = self._get_binner()
#     179 self._selection = selection
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\grouper.py:408, in Grouper._set_grouper(self, obj, sort, gpr_index)
#     404     indexer = self._indexer_deprecated = ax.array.argsort(
#     405         kind="mergesort", na_position="first"
#     406     )
#     407     ax = ax.take(indexer)
# --> 408     obj = obj.take(indexer, axis=self.axis)
#     410 # error: Incompatible types in assignment (expression has type
#     411 # "NDFrameT", variable has type "None")
#     412 self._obj_deprecated = obj  # type: ignore[assignment]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:877, in BaseBlockManager.take(self, indexer, axis, verify)
#     874 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     876 new_labels = self.axes[axis].take(indexer)
# --> 877 return self.reindex_indexer(
#     878     new_axis=new_labels,
#     879     indexer=indexer,
#     880     axis=axis,
#     881     allow_dups=True,
#     882     copy=None,
#     883 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:671, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
#     670     new_blocks = [
# --> 671         blk.take_nd(
#     672             indexer,
#     673             axis=1,
#     674             fill_value=(
#     675                 fill_value if fill_value is not None else blk.fill_value
#     676             ),
#     677         )
#     678         for blk in self.blocks
#     679     ]
#     681 new_axes = list(self.axes)
#     682 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1061, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1058     allow_fill = True
#    1060 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1061 new_values = algos.take_nd(
#    1062     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1063 )
#    1065 # Called from three places in managers, all of which satisfy
#    1066 #  these assertions
#    1067 if isinstance(self, ExtensionBlock):
#    1068     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1069     #  algos.take_nd call above.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py:118, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     117 arr = np.asarray(arr)
# --> 118 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py:158, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     156     out = np.empty(out_shape, dtype=dtype, order="F")
#     157 else:
# --> 158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
#     163 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 981. MiB for an array with shape (17, 7564541) and data type object
